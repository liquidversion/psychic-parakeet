# %% [markdown]
# <a href="https://colab.research.google.com/github/liquidversion/psychic-parakeet/blob/main/R66v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Install quickdraw package if not already installed
# !pip install quickdraw

# Step 2: Import essentials
from quickdraw import QuickDrawDataGroup
import matplotlib.pyplot as plt
import random

# %%
# These are valid Quick, Draw! categories
doodle_categories = ["light bulb", "cloud", "hammer", "airplane"]  # 🚀 Replaced rocket with airplane

# Load doodles from valid categories
doodles = [QuickDrawDataGroup(category) for category in doodle_categories]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4bf0205471c0> in <cell line: 0>()
#       3
#       4 # Load doodles from valid categories
# ----> 5 doodles = [QuickDrawDataGroup(category) for category in doodle_categories]
#
# <ipython-input-1-4bf0205471c0> in <listcomp>(.0)
#       3
#       4 # Load doodles from valid categories
# ----> 5 doodles = [QuickDrawDataGroup(category) for category in doodle_categories]
#
# NameError: name 'QuickDrawDataGroup' is not defined

# %%
# Step 1: Install the QuickDraw library (if not already installed)
# !pip install quickdraw

# Step 2: Import the class
from quickdraw import QuickDrawDataGroup

# Step 3: Define valid doodle categories
doodle_categories = ["light bulb", "cloud", "hammer", "airplane"]

# Step 4: Load the doodles
doodles = [QuickDrawDataGroup(category) for category in doodle_categories]
# Out:
# ...
# loading light bulb drawings
# load complete
# loading cloud drawings
# load complete
# loading hammer drawings
# load complete
# loading airplane drawings
# load complete

# %%
import matplotlib.pyplot as plt

# Create subplots for each doodle
fig, axs = plt.subplots(1, len(doodles), figsize=(15, 4))

for ax, group in zip(axs, doodles):
    drawing = group.get_drawing()
    drawing.draw(ax)
    ax.set_title(group.name.title())
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-f7fc55bf80b6> in <cell line: 0>()
#       6 for ax, group in zip(axs, doodles):
#       7     drawing = group.get_drawing()
# ----> 8     drawing.draw(ax)
#       9     ax.set_title(group.name.title())
#      10     ax.axis('off')
#
# AttributeError: 'QuickDrawing' object has no attribute 'draw'

# %%
import matplotlib.pyplot as plt

# Create subplots for each doodle
fig, axs = plt.subplots(1, len(doodles), figsize=(15, 4))

for ax, group in zip(axs, doodles):
    drawing = group.get_drawing()
    ax.imshow(drawing.get_image(), cmap='gray')  # ✅ fixed here
    ax.set_title(group.name.title())
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-6b78eb2a8869> in <cell line: 0>()
#       7     drawing = group.get_drawing()
#       8     ax.imshow(drawing.get_image(), cmap='gray')  # ✅ fixed here
# ----> 9     ax.set_title(group.name.title())
#      10     ax.axis('off')
#      11
#
# AttributeError: 'QuickDrawDataGroup' object has no attribute 'name'

# %%
import matplotlib.pyplot as plt

# Create subplots for each doodle
fig, axs = plt.subplots(1, len(doodles), figsize=(15, 4))

for ax, group in zip(axs, doodles):
    drawing = group.get_drawing()
    ax.imshow(drawing.get_image(), cmap='gray')  # ✅ fixed here
    ax.set_title(drawing.name.title())
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
from quickdraw import QuickDrawDataGroup, QUICK_DRAWING_NAMES
import matplotlib.pyplot as plt
import random

# Conceptual AI stages
labels = ["Research", "Data", "Testing", "Feedback"]

# Pick 4 random doodles
random_categories = random.sample(QUICK_DRAWING_NAMES, 4)

# Load 1 random drawing for each category
doodles = [QuickDrawDataGroup(cat).get_drawing() for cat in random_categories]

# Display with concept labels
fig, axs = plt.subplots(1, len(doodles), figsize=(15, 4))

for ax, drawing, label in zip(axs, doodles, labels):
    ax.imshow(drawing.get_image(), cmap='gray')
    ax.set_title(f"{label}\n({drawing.name.title()})")  # Concept + actual doodle name
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-c0687e783a26> in <cell line: 0>()
# ----> 1 from quickdraw import QuickDrawDataGroup, QUICK_DRAWING_NAMES
#       2 import matplotlib.pyplot as plt
#       3 import random
#       4
#       5 # Conceptual AI stages
#
# ImportError: cannot import name 'QUICK_DRAWING_NAMES' from 'quickdraw' (/usr/local/lib/python3.11/dist-packages/quickdraw/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import random
import matplotlib.pyplot as plt
from quickdraw import QuickDrawDataGroup

# ✅ Known list of valid Quick, Draw! categories
valid_doodles = [
    "airplane", "alarm clock", "ambulance", "angel", "animal migration", "ant", "anvil", "apple",
    "arm", "asparagus", "axe", "backpack", "banana", "bandage", "barn", "baseball", "baseball bat",
    "basket", "basketball", "bat", "bathtub", "beach", "bear", "beard", "bed", "bee", "belt", "bench",
    "bicycle", "binoculars", "bird", "birthday cake", "blackberry", "blueberry", "book", "boomerang",
    "bottlecap", "bowtie", "bracelet", "brain", "bread", "bridge", "broccoli", "broom", "bucket",
    "bulldozer", "bus", "bush", "butterfly", "cactus", "cake", "calculator", "calendar", "camel",
    "camera", "camouflage", "campfire", "candle", "cannon", "canoe", "car", "carrot", "castle", "cat",
    "ceiling fan", "cell phone", "cello", "chair", "chandelier", "church", "circle", "clarinet", "clock",
    "cloud", "coffee cup", "compass", "computer", "cookie", "cooler", "couch", "cow", "crab", "crayon",
    "crocodile", "crown", "cruise ship", "cup", "diamond", "dishwasher", "diving board", "dog", "dolphin",
    "donut", "door", "dragon", "dresser", "drill", "drums", "duck", "dumbbell", "ear", "elbow", "elephant",
    "envelope", "eraser", "eye", "eyeglasses", "face", "fan", "feather", "fence", "finger", "fire hydrant",
    "fireplace", "firetruck", "fish", "flamingo", "flashlight", "flip flops", "floor lamp", "flower",
    "flying saucer", "foot", "fork", "frog", "frying pan", "garden", "garden hose", "giraffe", "goatee",
    "golf club", "grapes", "grass", "guitar", "hamburger", "hammer", "hand", "harp", "hat", "headphones",
    "hedgehog", "helicopter", "helmet", "hexagon", "hockey puck", "hockey stick", "horse", "hospital",
    "hot air balloon", "hot dog", "hot tub", "hourglass", "house", "house plant", "hurricane", "ice cream",
    "jacket", "jail", "kangaroo", "key", "keyboard", "knee", "knife", "ladder", "lantern", "laptop",
    "leaf", "leg", "light bulb", "lighter", "lighthouse", "lightning", "line", "lion", "lipstick",
    "lobster", "lollipop", "mailbox", "map", "marker", "matches", "megaphone", "mermaid", "microphone",
    "microwave", "monkey", "moon", "mosquito", "motorbike", "mountain", "mouse", "moustache", "mouth",
    "mug", "mushroom", "nail", "necklace", "nose", "ocean", "octagon", "octopus", "onion", "oven", "owl",
    "paint can", "paintbrush", "palm tree", "panda", "pants", "paper clip", "parachute", "parrot",
    "passport", "peanut", "pear", "peas", "pencil", "penguin", "piano", "pickup truck", "picture frame",
    "pig", "pillow", "pineapple", "pizza", "pliers", "police car", "pond", "pool", "popsicle", "postcard",
    "potato", "power outlet", "purse", "rabbit", "raccoon", "radio", "rain", "rainbow", "rake", "remote control",
    "rhinoceros", "rifle", "river", "roller coaster", "rollerskates", "sailboat", "sandwich", "saw", "saxophone",
    "school bus", "scissors", "scorpion", "screwdriver", "sea turtle", "see saw", "shark", "sheep", "shoe",
    "shorts", "shovel", "sink", "skateboard", "skull", "skyscraper", "sleeping bag", "smiley face", "snail",
    "snake", "snorkel", "snowflake", "snowman", "soccer ball", "sock", "speedboat", "spider", "spoon",
    "spreadsheet", "square", "squiggle", "squirrel", "stairs", "star", "steak", "stereo", "stethoscope",
    "stitches", "stop sign", "stove", "strawberry", "streetlight", "string bean", "submarine", "suitcase",
    "sun", "swan", "sweater", "swing set", "sword", "syringe", "t-shirt", "table", "teapot", "teddy-bear",
    "telephone", "television", "tennis racquet", "tent", "The Eiffel Tower", "The Great Wall of China",
    "The Mona Lisa", "tiger", "toaster", "toe", "toilet", "tooth", "toothbrush", "toothpaste", "tornado",
    "tractor", "traffic light", "train", "tree", "triangle", "trombone", "truck", "trumpet", "tshirt",
    "turtle", "tv", "umbrella", "underwear", "van", "vase", "violin", "washing machine", "watermelon",
    "waterslide", "whale", "wheel", "windmill", "wine bottle", "wine glass", "wristwatch", "yoga", "zebra", "zigzag"
]

# Custom labels for your AI process
labels = ["Research", "Data", "Testing", "Feedback"]

# Pick 4 random valid doodles
random_categories = random.sample(valid_doodles, 4)
doodles = [QuickDrawDataGroup(cat).get_drawing() for cat in random_categories]

# Plot them with labels
fig, axs = plt.subplots(1, len(doodles), figsize=(15, 4))

for ax, drawing, label in zip(axs, doodles, labels):
    ax.imshow(drawing.get_image(), cmap='gray')
    ax.set_title(f"{label}\n({drawing.name.title()})")
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# downloading eyeglasses from https://storage.googleapis.com/quickdraw_dataset/full/binary/eyeglasses.bin
# download complete
# loading eyeglasses drawings
# load complete
# downloading rabbit from https://storage.googleapis.com/quickdraw_dataset/full/binary/rabbit.bin
# download complete
# loading rabbit drawings
# load complete
# downloading moustache from https://storage.googleapis.com/quickdraw_dataset/full/binary/moustache.bin
# download complete
# loading moustache drawings
# load complete
# downloading sea turtle from https://storage.googleapis.com/quickdraw_dataset/full/binary/sea turtle.bin
# download complete
# loading sea turtle drawings
# load complete

# %%
import matplotlib.pyplot as plt
from quickdraw import QuickDrawDataGroup

# Set fixed doodles that represent your AI stages
# (These are all valid Quick, Draw! categories)
concepts = {
    "Research": "book",            # or "brain"
    "Data": "bar graph",           # or "spreadsheet"
    "Testing": "microscope",       # or "beaker"
    "Feedback": "megaphone"        # or "ear"
}

# Load one drawing for each concept
doodles = [QuickDrawDataGroup(name).get_drawing() for name in concepts.values()]

# Display them with your concept labels
fig, axs = plt.subplots(1, len(doodles), figsize=(15, 4))

for ax, drawing, label in zip(axs, doodles, concepts.keys()):
    ax.imshow(drawing.get_image(), cmap='gray')
    ax.set_title(f"{label}\n({drawing.name.title()})")
    ax.axis('off')

plt.tight_layout()
plt.show()
✨ Result:
You’ll get:

Book for Research

Bar Graph for Data

Microscope for Testing

Megaphone for Feedback
# Out:
#   File "<ipython-input-11-e2a44183ab64>", line 26
#     ✨ Result:
#     ^
# SyntaxError: invalid character '✨' (U+2728)

# %%
import matplotlib.pyplot as plt
from quickdraw import QuickDrawDataGroup

# Set fixed doodles that represent your AI stages
# (These are all valid Quick, Draw! categories)
concepts = {
    "Research": "book",            # or "brain"
    "Data": "bar graph",           # or "spreadsheet"
    "Testing": "microscope",       # or "beaker"
    "Feedback": "megaphone"        # or "ear"
}

# Load one drawing for each concept
doodles = [QuickDrawDataGroup(name).get_drawing() for name in concepts.values()]

# Display them with your concept labels
fig, axs = plt.subplots(1, len(doodles), figsize=(15, 4))

for ax, drawing, label in zip(axs, doodles, concepts.keys()):
    ax.imshow(drawing.get_image(), cmap='gray')
    ax.set_title(f"{label}\n({drawing.name.title()})")
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# downloading book from https://storage.googleapis.com/quickdraw_dataset/full/binary/book.bin
# download complete
# loading book drawings
# load complete
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-77bed37a7e74> in <cell line: 0>()
#      12
#      13 # Load one drawing for each concept
# ---> 14 doodles = [QuickDrawDataGroup(name).get_drawing() for name in concepts.values()]
#      15
#      16 # Display them with your concept labels
#
# <ipython-input-12-77bed37a7e74> in <listcomp>(.0)
#      12
#      13 # Load one drawing for each concept
# ---> 14 doodles = [QuickDrawDataGroup(name).get_drawing() for name in concepts.values()]
#      15
#      16 # Display them with your concept labels
#
# /usr/local/lib/python3.11/dist-packages/quickdraw/data.py in __init__(self, name, recognized, max_drawings, refresh_data, print_messages, cache_dir)
#     233
# ...

# %%
import matplotlib.pyplot as plt
from quickdraw import QuickDrawDataGroup

# Only using doodles that exist in the dataset
concepts = {
    "Research": "book",
    "Data": "spreadsheet",
    "Testing": "microscope",
    "Feedback": "megaphone"
}

# Load one drawing for each concept
doodles = [QuickDrawDataGroup(name).get_drawing() for name in concepts.values()]

# Display them with your concept labels
fig, axs = plt.subplots(1, len(doodles), figsize=(15, 4))

for ax, drawing, label in zip(axs, doodles, concepts.keys()):
    ax.imshow(drawing.get_image(), cmap='gray')
    ax.set_title(f"{label}\n({drawing.name.title()})")
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# loading book drawings
# load complete
# downloading spreadsheet from https://storage.googleapis.com/quickdraw_dataset/full/binary/spreadsheet.bin
# download complete
# loading spreadsheet drawings
# load complete
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-f98d0efecf99> in <cell line: 0>()
#      11
#      12 # Load one drawing for each concept
# ---> 13 doodles = [QuickDrawDataGroup(name).get_drawing() for name in concepts.values()]
#      14
#      15 # Display them with your concept labels
#
# <ipython-input-14-f98d0efecf99> in <listcomp>(.0)
#      11
#      12 # Load one drawing for each concept
# ---> 13 doodles = [QuickDrawDataGroup(name).get_drawing() for name in concepts.values()]
#      14
#      15 # Display them with your concept labels
#
# ...

# %%
from quickdraw import QUICK_DRAWING_NAMES

# Print the full list of available categories
print(QUICK_DRAWING_NAMES)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-15-7c883e3a4344> in <cell line: 0>()
# ----> 1 from quickdraw import QUICK_DRAWING_NAMES
#       2
#       3 # Print the full list of available categories
#       4 print(QUICK_DRAWING_NAMES)
#
# ImportError: cannot import name 'QUICK_DRAWING_NAMES' from 'quickdraw' (/usr/local/lib/python3.11/dist-packages/quickdraw/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install quickdraw

# %%
import matplotlib.pyplot as plt
from quickdraw import QuickDrawDataGroup

# Set fixed doodles that represent your AI stages
concepts = {
    "Research": "book",           # Symbol for knowledge
    "Data": "spreadsheet",        # Represents structured data
    "Testing": "hammer",          # Represents testing/building
    "Feedback": "megaphone"       # Represents loud feedback
}

# Load one drawing for each concept
doodles = [QuickDrawDataGroup(name).get_drawing() for name in concepts.values()]

# Display them with your concept labels
fig, axs = plt.subplots(1, len(doodles), figsize=(15, 4))

for ax, drawing, label in zip(axs, doodles, concepts.keys()):
    ax.imshow(drawing.get_image(), cmap='gray')
    ax.set_title(f"{label}\n({drawing.name.title()})")
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# loading book drawings
# load complete
# loading spreadsheet drawings
# load complete
# loading hammer drawings
# load complete
# downloading megaphone from https://storage.googleapis.com/quickdraw_dataset/full/binary/megaphone.bin
# download complete
# loading megaphone drawings
# load complete

# %%
import matplotlib.pyplot as plt
from quickdraw import QuickDrawDataGroup

# Mode 1: Fixed Logic Mode
# Set fixed doodles that represent your AI stages
concepts = {
    "Research": "book",           # Symbol for knowledge
    "Data": "spreadsheet",        # Represents structured data
    "Testing": "hammer",          # Represents testing/building
    "Feedback": "megaphone"       # Represents loud feedback
}

# Load one drawing for each concept
doodles = [QuickDrawDataGroup(name).get_drawing() for name in concepts.values()]

# Display them with your concept labels
fig, axs = plt.subplots(1, len(doodles), figsize=(15, 4))

for ax, drawing, label in zip(axs, doodles, concepts.keys()):
    ax.imshow(drawing.get_image(), cmap='gray')
    ax.set_title(f"{label}\n({drawing.name.title()})")
    ax.axis('off')

plt.tight_layout()
plt.show()


# Mode 2: Random Doodles Mode
import random
from quickdraw import QUICK_DRAWING_NAMES

# Pick random doodles from the valid dataset
random_categories = random.sample(QUICK_DRAWING_NAMES, 4)
random_doodles = [QuickDrawDataGroup(cat).get_drawing() for cat in random_categories]

# Display them
fig, axs = plt.subplots(1, len(random_doodles), figsize=(15, 4))

for ax, drawing in zip(axs, random_doodles):
    ax.imshow(drawing.get_image(), cmap='gray')
    ax.set_title(f"Random Doodle: {drawing.name.title()}")
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# loading book drawings
# load complete
# loading spreadsheet drawings
# load complete
# loading hammer drawings
# load complete
# loading megaphone drawings
# load complete
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-ea13ba6f542b> in <cell line: 0>()
#      28 # Mode 2: Random Doodles Mode
#      29 import random
# ---> 30 from quickdraw import QUICK_DRAWING_NAMES
#      31
#      32 # Pick random doodles from the valid dataset
#
# ImportError: cannot import name 'QUICK_DRAWING_NAMES' from 'quickdraw' (/usr/local/lib/python3.11/dist-packages/quickdraw/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# ...

# %%
import matplotlib.pyplot as plt
from quickdraw import QuickDrawDataGroup
import random

# Mode 1: Fixed Logic Mode
# Set fixed doodles that represent your AI stages
concepts = {
    "Research": "book",           # Symbol for knowledge
    "Data": "spreadsheet",        # Represents structured data
    "Testing": "hammer",          # Represents testing/building
    "Feedback": "megaphone"       # Represents loud feedback
}

# Load one drawing for each concept
doodles = [QuickDrawDataGroup(name).get_drawing() for name in concepts.values()]

# Display them with your concept labels
fig, axs = plt.subplots(1, len(doodles), figsize=(15, 4))

for ax, drawing, label in zip(axs, doodles, concepts.keys()):
    ax.imshow(drawing.get_image(), cmap='gray')
    ax.set_title(f"{label}\n({drawing.name.title()})")
    ax.axis('off')

plt.tight_layout()
plt.show()


# Mode 2: Random Doodles Mode
# Hardcoded list of valid categories (subset of Quick, Draw! categories)
valid_doodles = [
    "airplane", "alarm clock", "ambulance", "apple", "book", "bridge", "cat", "cloud",
    "cow", "dog", "elephant", "flower", "guitar", "hammer", "house", "light bulb",
    "microscope", "moon", "rainbow", "rocket", "star", "toothbrush", "umbrella"
]

# Pick random doodles from the valid dataset
random_categories = random.sample(valid_doodles, 4)
random_doodles = [QuickDrawDataGroup(cat).get_drawing() for cat in random_categories]

# Display them
fig, axs = plt.subplots(1, len(random_doodles), figsize=(15, 4))

for ax, drawing in zip(axs, random_doodles):
    ax.imshow(drawing.get_image(), cmap='gray')
    ax.set_title(f"Random Doodle: {drawing.name.title()}")
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# loading book drawings
# load complete
# loading spreadsheet drawings
# load complete
# loading hammer drawings
# load complete
# loading megaphone drawings
# load complete
# downloading bridge from https://storage.googleapis.com/quickdraw_dataset/full/binary/bridge.bin
# download complete
# loading bridge drawings
# load complete
# downloading umbrella from https://storage.googleapis.com/quickdraw_dataset/full/binary/umbrella.bin
# download complete
# loading umbrella drawings
# load complete
# downloading apple from https://storage.googleapis.com/quickdraw_dataset/full/binary/apple.bin
# download complete
# loading apple drawings
# load complete
# loading hammer drawings
# load complete

# %%
import matplotlib.pyplot as plt
from quickdraw import QuickDrawDataGroup
import random

# Mode 1: Fixed Logic Mode
# Set fixed doodles that represent your AI stages
concepts = {
    "Research": "book",           # Symbol for knowledge
    "Data": "spreadsheet",        # Represents structured data
    "Testing": "hammer",          # Represents testing/building
    "Feedback": "megaphone"       # Represents loud feedback
}

# Load one drawing for each concept
doodles = [QuickDrawDataGroup(name).get_drawing() for name in concepts.values()]

# Display them with your concept labels
fig, axs = plt.subplots(1, len(doodles), figsize=(15, 4))

for ax, drawing, label in zip(axs, doodles, concepts.keys()):
    ax.imshow(drawing.get_image(), cmap='gray')
    ax.set_title(f"{label}\n({drawing.name.title()})")
    ax.axis('off')

plt.tight_layout()
plt.show()


# Mode 2: Fun, Random Doodles Mode with Logical Representation
# Define possible categories to select from
valid_doodles = [
    "airplane", "alarm clock", "ambulance", "apple", "book", "bridge", "cat", "cloud",
    "cow", "dog", "elephant", "flower", "guitar", "hammer", "house", "light bulb",
    "microscope", "moon", "rainbow", "rocket", "star", "toothbrush", "umbrella"
]

# Randomly pick 4 doodles
random_categories = random.sample(valid_doodles, 4)
random_doodles = [QuickDrawDataGroup(cat).get_drawing() for cat in random_categories]

# Logic for matching doodles to concepts
doodle_concepts = {
    "Data": ["spreadsheet", "bar graph", "pie chart", "database", "calculator"],  # Data-related symbols
    "Testing": ["hammer", "microscope", "toothbrush", "glasses"],  # Tools for testing/inspection
    "Research": ["book", "brain", "notebook", "library"],  # Knowledge/reading
    "Feedback": ["megaphone", "ear", "mouth", "comment", "speaker"],  # Communication and feedback
}

# Display the selected random doodles
fig, axs = plt.subplots(1, len(random_doodles), figsize=(15, 4))

for ax, drawing, category in zip(axs, random_doodles, random_categories):
    # Try to match doodles to AI stages
    matched_category = None
    for key, doodle_list in doodle_concepts.items():
        if drawing.name in doodle_list:
            matched_category = key
            break

    if matched_category is None:
        matched_category = "Unknown"  # If no match found

    ax.imshow(drawing.get_image(), cmap='gray')
    ax.set_title(f"Random Doodle: {drawing.name.title()}\nMapped to {matched_category}")
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# loading book drawings
# load complete
# loading spreadsheet drawings
# load complete
# loading hammer drawings
# load complete
# loading megaphone drawings
# load complete
# loading hammer drawings
# load complete
# downloading house from https://storage.googleapis.com/quickdraw_dataset/full/binary/house.bin
# download complete
# loading house drawings
# load complete
# downloading elephant from https://storage.googleapis.com/quickdraw_dataset/full/binary/elephant.bin
# download complete
# loading elephant drawings
# load complete
# loading light bulb drawings
# load complete

# %%
async function recognizeDoodle(imageData) {
    try {
        const result = await quickDraw.predict(imageData);
        if (result && result.name) {
            recognizedDoodles.push(result.name.toLowerCase());
            displayRoadmap();
            document.getElementById('status').innerText = 'Status: Doodle recognized and mapped to roadmap!';
        }
    } catch (error) {
        document.getElementById('status').innerText = 'Error recognizing doodle. Please try again.';
    }
}
# Out:
#   File "<ipython-input-1-b6875ec8f8d1>", line 1
#     async function recognizeDoodle(imageData) {
#           ^
# SyntaxError: invalid syntax
